# %% [markdown]
# We can use the provided stylesheets under ./support/stylesheets as interpreters to extract the source data xml files.

# %%
import pandas as pd
from lxml import etree
import os

def xslt_transform_to_csv(xslt_path, xml_path, csv_path):
  # Load the XSLT stylesheet
  with open(xslt_path, 'r') as f:
      xsl = etree.parse(f)

  # Load the XML document
  with open(xml_path, 'r') as f:
      xml = etree.parse(f)

  # Create an XSLT transformer
  transform = etree.XSLT(xsl)

  # Apply the transformation
  result = transform(xml)

  # Write the result to a file
  with open('temp.xml', 'wb') as f:
      f.write(etree.tostring(result))

  # Read the XML data into a DataFrame
  df = pd.read_xml('temp.xml')

  # Write the DataFrame to a CSV file
  df.to_csv(csv_path, index=False)

  # Delete the temporary XML file
  if os.path.exists('temp.xml'):
      os.remove('temp.xml')
  else:
      print("The file does not exist")

path_to_xslt_stylesheet = '../sourceandrenderingpipeline/support/stylesheets/extractsrtemplatesforpixelmed.xsl'
path_to_xml_document = '../sourceandrenderingpipeline/source/docbook/part16/part16.xml'
path_to_output_csv = '../P16_extract_srtemplates.csv'

xslt_transform_to_csv(path_to_xslt_stylesheet, path_to_xml_document, path_to_output_csv)

# %%
from lxml import etree

path_to_xslt_stylesheet = '../sourceandrenderingpipeline/support/stylesheets/extractsrtemplatesforpixelmed.xsl'
path_to_xml_document = '../sourceandrenderingpipeline/source/docbook/part16/part16.xml'
path_to_output_csv = '../P16_extract_srtemplates.csv'

with open(path_to_xslt_stylesheet, 'r') as f:
    xsl = etree.parse(f)

# Load the XML document
with open(path_to_xml_document, 'r') as f:
    xml = etree.parse(f)

# Create an XSLT transformer
transform = etree.XSLT(xsl)

# Apply the transformation
result = transform(xml)

# Write the result to a file
with open('temp.xml', 'wb') as f:
    f.write(etree.tostring(result))
    
# Load and parse the XML data from 'temp.xml'
with open('temp.xml', 'rb') as f:
    xml_content = f.read()

# Parse the XML content
xml_tree = etree.fromstring(xml_content)

# Print the entire XML content (formatted)
print(etree.tostring(xml_tree, pretty_print=True, encoding='utf-8').decode('utf-8'))
# Out:
# <definetemplates xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.pixelmed.com/namespaces/contextgroups" xsi:schemaLocation="http://www.pixelmed.com/namespaces/contextgroups http://www.pixelmed.com/schemas/contextgroups.xsd">
#   <definetemplate tid="300" name="Measurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M">
#       <templatecontentitem row="2" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="n" requiredType="U"/>
#       <templatecontentitem row="3" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="370129005" csdConceptName="SCT" cmConceptName="Measurement Method"/>
#       <templatecontentitem row="4" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121401" csdConceptName="DCM" cmConceptName="Derivation"/>
#       <templatecontentitem row="5" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="363698007" csdConceptName="SCT" cmConceptName="Finding Site">
#         <templatecontentitem row="6" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="272741003" csdConceptName="SCT" cmConceptName="Laterality" valueSetCID="244" valueSetBDE="D">
#           <!--$TargetSiteLaterality, Defaults to DCID 244-->
#         </templatecontentitem>
#         <templatecontentitem row="7" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="106233006" csdConceptName="SCT" cmConceptName="Topographical modifier"/>
#       </templatecontentitem>
#       <includetemplate row="8" tid="310" relationship="HAS PROPERTIES" vmmin="1" vmmax="1" requiredType="U"/>
#       <!--$RefAuthority = $RefAuthority, $RangeAuthority = $RangeAuthority-->
#       <templatecontentitem row="9" relationship="INFERRED FROM" valueType="NUM" vmmin="1" vmmax="n" requiredType="UC">
#         <!--XOR Row 10-->
#       </templatecontentitem>
#       <templatecontentitem row="10" relationship="R-INFERRED FROM" valueType="NUM" vmmin="1" vmmax="n" requiredType="UC">
#         <!--XOR Row 9-->
#       </templatecontentitem>
#       <includetemplate row="11" tid="315" relationship="INFERRED FROM" vmmin="1" vmmax="1" requiredType="UC"/>
#       <!--$Equation = $Equation-->
#       <!--XOR Row 12-->
#       <templatecontentitem row="12" relationship="INFERRED FROM" valueType="TEXT" vmmin="1" vmmax="1" requiredType="UC" conceptNameCID="228" conceptNameBDE="D">
#         <!--XOR Row 11-->
#       </templatecontentitem>
#       <includetemplate row="13" tid="320" relationship="" vmmin="1" vmmax="n" requiredType="U"/>
#       <!--$Purpose = $ImagePurpose-->
#       <includetemplate row="14" tid="321" relationship="" vmmin="1" vmmax="n" requiredType="U"/>
#       <!--$Purpose = $WavePurpose-->
#       <includetemplate row="15" tid="1000" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="16" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121050" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Concept Name"/>
#       <templatecontentitem row="16b" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121050" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Concept Name"/>
#       <includetemplate row="17" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="18" relationship="INFERRED FROM" valueType="COMPOSITE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="126100" csdConceptName="DCM" cmConceptName="Real World Value Map used for measurement"/>
#       <includetemplate row="19" tid="4019" relationship="HAS CONCEPT MOD" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="310" name="MeasurementProperties" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121402" csdConceptName="DCM" cmConceptName="Normality" valueSetCID="222" valueSetBDE="D"/>
#     <includetemplate row="2" tid="311" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     <!--$RefAuthority = $RefAuthority-->
#     <includetemplate row="3" tid="312" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     <!--$RangeAuthority = $RangeAuthority-->
#     <templatecontentitem row="4" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121403" csdConceptName="DCM" cmConceptName="Level of Significance" valueSetCID="220" valueSetBDE="D"/>
#     <templatecontentitem row="5" relationship="" valueType="NUM" vmmin="1" vmmax="n" requiredType="U" conceptNameCID="225" conceptNameBDE="D"/>
#     <templatecontentitem row="6" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121404" csdConceptName="DCM" cmConceptName="Selection Status" valueSetCID="224" valueSetBDE="D"/>
#   </definetemplate>
#   <definetemplate tid="311" name="MeasurementStatisticalProperties" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="n" requiredType="M" conceptNameCID="221" conceptNameBDE="D"/>
#     <templatecontentitem row="2" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121405" csdConceptName="DCM" cmConceptName="Population description"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121406" csdConceptName="DCM" cmConceptName="Reference Authority">
#       <!--XOR Row 4-->
#     </templatecontentitem>
#     <templatecontentitem row="4" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121406" csdConceptName="DCM" cmConceptName="Reference Authority">
#       <!--XOR Row 3-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="312" name="NormalRangeProperties" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="n" requiredType="M" conceptNameCID="223" conceptNameBDE="D"/>
#     <templatecontentitem row="2" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121407" csdConceptName="DCM" cmConceptName="Normal Range description"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121408" csdConceptName="DCM" cmConceptName="Normal Range Authority">
#       <!--XOR Row 4-->
#     </templatecontentitem>
#     <templatecontentitem row="4" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121408" csdConceptName="DCM" cmConceptName="Normal Range Authority">
#       <!--XOR Row 3-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="315" name="EquationorTable" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="228" conceptNameBDE="D">
#       <templatecontentitem row="2" relationship="HAS PROPERTIES" valueType="NUM" vmmin="1" vmmax="n" requiredType="U"/>
#       <templatecontentitem row="3" relationship="R-HAS PROPERTIES" valueType="NUM" vmmin="1" vmmax="n" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="320" name="ImageorSpatialCoordinates" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 2, 3, 6-->
#     </templatecontentitem>
#     <templatecontentitem row="2" relationship="R-INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 1, 3, 6-->
#     </templatecontentitem>
#     <templatecontentitem row="3" relationship="INFERRED FROM" valueType="SCOORD" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 1, 2, 6-->
#       <templatecontentitem row="4" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#         <!--XOR Row 5-->
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#         <!--XOR Row 4-->
#       </templatecontentitem>
#     </templatecontentitem>
#     <templatecontentitem row="6" relationship="INFERRED FROM" valueType="SCOORD3D" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 1, 2, 3-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="321" name="WaveformorTemporalCoordinates" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="INFERRED FROM" valueType="WAVEFORM" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 2, 3-->
#     </templatecontentitem>
#     <templatecontentitem row="2" relationship="R-INFERRED FROM" valueType="WAVEFORM" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 1, 3-->
#     </templatecontentitem>
#     <templatecontentitem row="3" relationship="INFERRED FROM" valueType="TCOORD" vmmin="1" vmmax="1" requiredType="MC">
#       <!--XOR Rows 1, 2-->
#       <templatecontentitem row="4" relationship="SELECTED FROM" valueType="WAVEFORM" vmmin="1" vmmax="1" requiredType="MC">
#         <!--XOR Row 5-->
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="R-SELECTED FROM" valueType="WAVEFORM" vmmin="1" vmmax="1" requiredType="MC">
#         <!--XOR Row 4-->
#       </templatecontentitem>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="350" name="ReferencestoSupportingEvidence" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="IMAGE" vmmin="1" vmmax="n" requiredType="U" conceptNameCID="7003" conceptNameBDE="B"/>
#     <templatecontentitem row="2" relationship="" valueType="SCOORD" vmmin="1" vmmax="n" requiredType="U" conceptNameCID="7003" conceptNameBDE="B">
#       <templatecontentitem row="3" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="M"/>
#     </templatecontentitem>
#     <templatecontentitem row="4" relationship="" valueType="COMPOSITE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="122073" csdConceptName="DCM" cmConceptName="Current procedure evidence">
#       <templatecontentitem row="5" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121144" csdConceptName="DCM" cmConceptName="Document Title"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="351" name="PreviousReports" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="111549" csdConceptName="DCM" cmConceptName="Previous Reports">
#       <templatecontentitem row="2" relationship="CONTAINS" valueType="COMPOSITE" vmmin="1" vmmax="n" requiredType="M"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="400" name="ReferenceLocation" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="128772" csdConceptName="DCM" cmConceptName="Reference Basis" valueSetCID="1001" valueSetBDE="B"/>
#     <templatecontentitem row="2" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="128773" csdConceptName="DCM" cmConceptName="Reference Geometry" valueSetCID="1010" valueSetBDE="B"/>
#   </definetemplate>
#   <definetemplate tid="1000" name="Quotation" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS OBS CONTEXT" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121001" csdConceptName="DCM" cmConceptName="Quotation Mode">
#       <!--EV (121003, DCM, "Document"), EV (121004, DCM, "Verbal")-->
#     </templatecontentitem>
#     <templatecontentitem row="2" relationship="HAS OBS CONTEXT" valueType="COMPOSITE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121002" csdConceptName="DCM" cmConceptName="Quoted Source">
#       <!--Required if quoted material source is a DICOM composite object-->
#     </templatecontentitem>
#     <includetemplate row="3" tid="1001" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="M"/>
#   </definetemplate>
#   <definetemplate tid="1001" name="ObservationContext" root="F" extensible="F" ordersignificant="T">
#     <includetemplate row="1" tid="1002" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="n" requiredType="MC"/>
#     <!--Defaults to the Attributes of the Author Observer Sequence (0040,A078), or the Verifying Observer Sequence (0040,A073) if the Author Observer Sequence is not present-->
#     <!--Required if all aspects of observer context are not inherited.-->
#     <includetemplate row="2" tid="1005" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="MC"/>
#     <!--Required if all aspects of procedure context are not inherited.-->
#     <includetemplate row="3" tid="1006" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="MC"/>
#     <!--Required if all aspects of observation subject context are not inherited.-->
#   </definetemplate>
#   <definetemplate tid="1002" name="ObserverContext" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS OBS CONTEXT" valueType="CODE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121005" csdConceptName="DCM" cmConceptName="Observer Type" valueSetCID="270" valueSetBDE="D">
#       <!--DCID 270, Defaults to (121006, DCM, "Person")-->
#       <!--IF Observer type is device-->
#     </templatecontentitem>
#     <includetemplate row="2" tid="1003" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="MC"/>
#     <!--IFF Row 1 value = (121006, DCM, "Person") or Row 1 is absent-->
#     <includetemplate row="3" tid="1004" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="MC"/>
#     <!--IFF Row 1 value = (121007, DCM, "Device")-->
#     <includetemplate row="4" tid="1015" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#   </definetemplate>
#   <definetemplate tid="1003" name="PersonObserverIdentifyingAttributes" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="PNAME" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121008" csdConceptName="DCM" cmConceptName="Person Observer Name"/>
#     <templatecontentitem row="1a" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="128774" csdConceptName="DCM" cmConceptName="Person Observer's Login Name"/>
#     <templatecontentitem row="2" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121009" csdConceptName="DCM" cmConceptName="Person Observer's Organization Name"/>
#     <templatecontentitem row="3" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121010" csdConceptName="DCM" cmConceptName="Person Observer's Role in the Organization" valueSetCID="7452" valueSetBDE="B"/>
#     <templatecontentitem row="4" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121011" csdConceptName="DCM" cmConceptName="Person Observer's Role in this Procedure" valueSetCID="7453" valueSetBDE="B">
#       <templatecontentitem row="5" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="128775" csdConceptName="DCM" cmConceptName="Identifier within Person Observer's Role"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1004" name="DeviceObserverIdentifyingAttributes" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121012" csdConceptName="DCM" cmConceptName="Device Observer UID"/>
#     <templatecontentitem row="2" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121013" csdConceptName="DCM" cmConceptName="Device Observer Name"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121014" csdConceptName="DCM" cmConceptName="Device Observer Manufacturer"/>
#     <templatecontentitem row="4" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121015" csdConceptName="DCM" cmConceptName="Device Observer Model Name"/>
#     <templatecontentitem row="5" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121016" csdConceptName="DCM" cmConceptName="Device Observer Serial Number"/>
#     <templatecontentitem row="6" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121017" csdConceptName="DCM" cmConceptName="Device Observer Physical Location During Observation"/>
#     <templatecontentitem row="7" relationship="" valueType="CODE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="113876" csdConceptName="DCM" cmConceptName="Device Role in Procedure" valueSetCID="7445" valueSetBDE="B"/>
#     <templatecontentitem row="8" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="110119" csdConceptName="DCM" cmConceptName="Station AE Title"/>
#     <templatecontentitem row="9" relationship="" valueType="UIDREF" vmmin="1" vmmax="n" requiredType="U" cvConceptName="121061" csdConceptName="DCM" cmConceptName="Device Observer Manufacturer Class UID"/>
#     <templatecontentitem row="10" relationship="" valueType="CONTAINER" vmmin="1" vmmax="n" requiredType="U" cvConceptName="121000" csdConceptName="DCM" cmConceptName="Unique Device Identifiers">
#       <templatecontentitem row="11" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="74711-3" csdConceptName="LN" cmConceptName="Unique Device Identifier"/>
#       <templatecontentitem row="12" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="120999" csdConceptName="DCM" cmConceptName="Device Description"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1005" name="ProcedureStudyContext" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121018" csdConceptName="DCM" cmConceptName="Procedure Study Instance UID"/>
#     <templatecontentitem row="2" relationship="" valueType="UIDREF" vmmin="1" vmmax="n" requiredType="U" cvConceptName="121019" csdConceptName="DCM" cmConceptName="Procedure Study Component UID"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121020" csdConceptName="DCM" cmConceptName="Placer Number">
#       <templatecontentitem row="4" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="110190" csdConceptName="DCM" cmConceptName="Issuer of Identifier"/>
#     </templatecontentitem>
#     <templatecontentitem row="5" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121021" csdConceptName="DCM" cmConceptName="Filler Number">
#       <templatecontentitem row="6" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="110190" csdConceptName="DCM" cmConceptName="Issuer of Identifier"/>
#     </templatecontentitem>
#     <templatecontentitem row="7" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121022" csdConceptName="DCM" cmConceptName="Accession Number">
#       <templatecontentitem row="8" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="110190" csdConceptName="DCM" cmConceptName="Issuer of Identifier"/>
#     </templatecontentitem>
#     <templatecontentitem row="9" relationship="" valueType="CODE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="121023" csdConceptName="DCM" cmConceptName="Procedure Code"/>
#   </definetemplate>
#   <definetemplate tid="1006" name="SubjectContext" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121024" csdConceptName="DCM" cmConceptName="Subject Class" valueSetCID="271" valueSetBDE="D">
#       <!--DCID 271, Defaults to (121025, DCM, "Patient")-->
#       <!--IF subject is not the Patient-->
#     </templatecontentitem>
#     <includetemplate row="2" tid="1007" relationship="" vmmin="1" vmmax="1" requiredType="UC"/>
#     <!--May be used for human or animal patients-->
#     <!--IFF Row 1 value = (121025, DCM, "Patient") or Row 1 is absent-->
#     <includetemplate row="3" tid="1008" relationship="" vmmin="1" vmmax="1" requiredType="UC"/>
#     <!--May be used for human or animal fetuses-->
#     <!--IFF Row 1 value = (121026, DCM, "Fetus")-->
#     <includetemplate row="4" tid="1009" relationship="" vmmin="1" vmmax="1" requiredType="UC"/>
#     <!--IFF Row 1 value = (121027, DCM, "Specimen")-->
#     <includetemplate row="5" tid="1010" relationship="" vmmin="1" vmmax="1" requiredType="UC"/>
#     <!--IFF Row 1 value = (121192, DCM, "Device Subject")-->
#   </definetemplate>
#   <definetemplate tid="1007" name="SubjectContext,Patient" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121028" csdConceptName="DCM" cmConceptName="Subject UID"/>
#     <templatecontentitem row="2" relationship="" valueType="PNAME" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121029" csdConceptName="DCM" cmConceptName="Subject Name">
#       <!--Required if not inherited.-->
#     </templatecontentitem>
#     <templatecontentitem row="3" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121030" csdConceptName="DCM" cmConceptName="Subject ID">
#       <!--Required if not inherited.-->
#     </templatecontentitem>
#     <templatecontentitem row="4" relationship="" valueType="DATE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121031" csdConceptName="DCM" cmConceptName="Subject Birth Date"/>
#     <templatecontentitem row="5" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121032" csdConceptName="DCM" cmConceptName="Subject Sex" valueSetCID="7455" valueSetBDE="D">
#       <!--Defaults to value equivalent to Value of Patient's Sex (0010,0040) of the , DCID 7455-->
#     </templatecontentitem>
#     <templatecontentitem row="6" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121033" csdConceptName="DCM" cmConceptName="Subject Age" unitsCID="7456" unitsBDE="D">
#       <!--Defaults to value equivalent to Value of Patient's Age (0010,1010) of the , UNITS = DCID 7456-->
#     </templatecontentitem>
#     <templatecontentitem row="7" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121034" csdConceptName="DCM" cmConceptName="Subject Species" valueSetCID="7454" valueSetBDE="D">
#       <!--DCID 7454, Defaults to Value of Patient Species Code Sequence (0010,2202) of the , or if absent, (337915000, SCT, "Homo sapiens").-->
#       <!--Required if not inherited.-->
#     </templatecontentitem>
#     <templatecontentitem row="8" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121035" csdConceptName="DCM" cmConceptName="Subject Breed" valueSetCID="7480" valueSetBDE="D">
#       <!--Defaults to Value of Patient Breed Code Sequence (0010,2293) of the , DCID 7480-->
#     </templatecontentitem>
#     <templatecontentitem row="9" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="415229000" csdConceptName="SCT" cmConceptName="Racial group" valueSetCID="6099" valueSetBDE="D">
#       <!--Defaults to the coded equivalent of the text Value of Ethnic Group (0010,2160) of the , which is defined as "race or ethnic group", DCID 6099-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1008" name="SubjectContext,Fetus" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="PNAME" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121036" csdConceptName="DCM" cmConceptName="Mother of fetus"/>
#     <templatecontentitem row="2" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121028" csdConceptName="DCM" cmConceptName="Subject UID"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121030" csdConceptName="DCM" cmConceptName="Subject ID">
#       <!--IF Row 4 is absent-->
#     </templatecontentitem>
#     <templatecontentitem row="4" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="11951-1" csdConceptName="LN" cmConceptName="Fetus ID">
#       <!--IF Row 3 is absent-->
#     </templatecontentitem>
#     <templatecontentitem row="5" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="11878-6" csdConceptName="LN" cmConceptName="Number of Fetuses by US" cvUnits="1" csdUnits="UCUM" cmUnits="no units">
#       <!--XOR Row 6-->
#     </templatecontentitem>
#     <templatecontentitem row="6" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="55281-0" csdConceptName="LN" cmConceptName="Number of Fetuses" cvUnits="1" csdUnits="UCUM" cmUnits="no units">
#       <!--XOR Row 5-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1009" name="SubjectContext,Specimen" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121039" csdConceptName="DCM" cmConceptName="Specimen UID"/>
#     <includetemplate row="2" tid="1007" relationship="" vmmin="1" vmmax="1" requiredType="UC"/>
#     <!--IFF the source of the specimen is a human or animal patient-->
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121041" csdConceptName="DCM" cmConceptName="Specimen Identifier"/>
#     <templatecontentitem row="4" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="111724" csdConceptName="DCM" cmConceptName="Issuer of Specimen Identifier"/>
#     <templatecontentitem row="5" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="371439000" csdConceptName="SCT" cmConceptName="Specimen Type" valueSetCID="8103" valueSetBDE="D"/>
#     <templatecontentitem row="6" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="111700" csdConceptName="DCM" cmConceptName="Specimen Container Identifier"/>
#   </definetemplate>
#   <definetemplate tid="1010" name="SubjectContext,Device" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121193" csdConceptName="DCM" cmConceptName="Device Subject Name"/>
#     <templatecontentitem row="2" relationship="" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121198" csdConceptName="DCM" cmConceptName="Device Subject UID"/>
#     <templatecontentitem row="3" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121194" csdConceptName="DCM" cmConceptName="Device Subject Manufacturer"/>
#     <templatecontentitem row="4" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121195" csdConceptName="DCM" cmConceptName="Device Subject Model Name"/>
#     <templatecontentitem row="5" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121196" csdConceptName="DCM" cmConceptName="Device Subject Serial Number"/>
#     <templatecontentitem row="6" relationship="" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121197" csdConceptName="DCM" cmConceptName="Device Subject Physical Location during observation"/>
#   </definetemplate>
#   <definetemplate tid="1015" name="PersonObserverDescription" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="128003" csdConceptName="DCM" cmConceptName="Reader Specialty" valueSetCID="7449" valueSetBDE="D">
#       <templatecontentitem row="2" relationship="HAS PROPERTIES" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" cvConceptName="C54627" csdConceptName="NCIt" cmConceptName="Experience" cvUnits="a" csdUnits="UCUM" cmUnits="Year"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1020" name="PersonParticipant" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="PNAME" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113870" csdConceptName="DCM" cmConceptName="Person Name">
#       <templatecontentitem row="2" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113875" csdConceptName="DCM" cmConceptName="Person Role in Procedure"/>
#       <templatecontentitem row="3" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113871" csdConceptName="DCM" cmConceptName="Person ID"/>
#       <templatecontentitem row="4" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113872" csdConceptName="DCM" cmConceptName="Person ID Issuer"/>
#       <templatecontentitem row="5" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113873" csdConceptName="DCM" cmConceptName="Organization Name"/>
#       <templatecontentitem row="6" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113874" csdConceptName="DCM" cmConceptName="Person Role in Organization" valueSetCID="7452" valueSetBDE="B"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1021" name="DeviceParticipant" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113876" csdConceptName="DCM" cmConceptName="Device Role in Procedure">
#       <templatecontentitem row="2" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113877" csdConceptName="DCM" cmConceptName="Device Name"/>
#       <templatecontentitem row="3" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113878" csdConceptName="DCM" cmConceptName="Device Manufacturer"/>
#       <templatecontentitem row="4" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113879" csdConceptName="DCM" cmConceptName="Device Model Name"/>
#       <templatecontentitem row="5" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="113880" csdConceptName="DCM" cmConceptName="Device Serial Number"/>
#       <templatecontentitem row="6" relationship="HAS PROPERTIES" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121012" csdConceptName="DCM" cmConceptName="Device Observer UID"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1200" name="LanguageDesignation" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121045" csdConceptName="DCM" cmConceptName="Language" valueSetCID="5000" valueSetBDE="D">
#       <templatecontentitem row="2" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121046" csdConceptName="DCM" cmConceptName="Country of Language" valueSetCID="5001" valueSetBDE="D"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1201" name="LanguageofValue" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121047" csdConceptName="DCM" cmConceptName="Language of Value" valueSetCID="5000" valueSetBDE="D">
#       <templatecontentitem row="2" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121046" csdConceptName="DCM" cmConceptName="Country of Language" valueSetCID="5001" valueSetBDE="D"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1202" name="LanguageofNameandValue" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121048" csdConceptName="DCM" cmConceptName="Language of Name and Value" valueSetCID="5000" valueSetBDE="D">
#       <templatecontentitem row="2" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121046" csdConceptName="DCM" cmConceptName="Country of Language" valueSetCID="5001" valueSetBDE="D"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1204" name="LanguageofContentItemandDescendants" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121049" csdConceptName="DCM" cmConceptName="Language of Content Item and Descendants" valueSetCID="5000" valueSetBDE="D">
#       <templatecontentitem row="2" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121046" csdConceptName="DCM" cmConceptName="Country of Language" valueSetCID="5001" valueSetBDE="D"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1210" name="EquivalentMeaning(s)ofConceptName" root="F" extensible="F" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="n" requiredType="MC" cvConceptName="121050" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Concept Name">
#       <!--XOR Row 3-->
#       <includetemplate row="2" tid="1201" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#     <templatecontentitem row="3" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="n" requiredType="MC" cvConceptName="121050" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Concept Name">
#       <!--XOR Row 1-->
#       <includetemplate row="4" tid="1201" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1211" name="EquivalentMeaning(s)ofValue" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="TEXT" vmmin="1" vmmax="n" requiredType="MC" cvConceptName="121051" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Value">
#       <!--XOR Row 3-->
#       <includetemplate row="2" tid="1201" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#     <templatecontentitem row="3" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="n" requiredType="MC" cvConceptName="121051" csdConceptName="DCM" cmConceptName="Equivalent Meaning of Value">
#       <!--XOR Row 1-->
#       <includetemplate row="4" tid="1201" relationship="" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1350" name="NegationModifier,PresenceofFinding" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121052" csdConceptName="DCM" cmConceptName="Presence of property" valueSetCID="240" valueSetBDE="D"/>
#   </definetemplate>
#   <definetemplate tid="1400" name="LinearMeasurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="7470" conceptNameBDE="D" unitsCID="7460" unitsBDE="D">
#       <templatecontentitem row="2" relationship="INFERRED FROM" valueType="SCOORD" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121055" csdConceptName="DCM" cmConceptName="Path">
#         <!--XOR Row 5-->
#         <templatecontentitem row="3" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 4-->
#         </templatecontentitem>
#         <templatecontentitem row="4" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 3-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="INFERRED FROM" valueType="SCOORD" vmmin="2" vmmax="n" requiredType="UC" cvConceptName="121230" csdConceptName="DCM" cmConceptName="Path Vertex">
#         <!--XOR Row 2-->
#         <templatecontentitem row="6" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 7-->
#         </templatecontentitem>
#         <templatecontentitem row="7" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 6-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <includetemplate row="8" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1401" name="AreaMeasurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="7471" conceptNameBDE="D" unitsCID="7461" unitsBDE="D">
#       <!--Value shall be > 0, UNITS = DCID 7461-->
#       <templatecontentitem row="2" relationship="INFERRED FROM" valueType="SCOORD" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121056" csdConceptName="DCM" cmConceptName="Area Outline">
#         <!--IF concept name of Row 1 = (131184002, SCT, "Area of defined region"), and IFF Row 5 or 6 not present.-->
#         <templatecontentitem row="3" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 4-->
#         </templatecontentitem>
#         <templatecontentitem row="4" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 3-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121214" csdConceptName="DCM" cmConceptName="Referenced Segmentation Frame">
#         <!--IF concept name of Row 1 = (131184002, SCT, "Area of defined region"), and IFF Row 2 or 6 not present.-->
#       </templatecontentitem>
#       <templatecontentitem row="6" relationship="R- INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#         <!--IF concept name of Row 1 = (131184002, SCT, "Area of defined region"), and IFF Row 2 or 5 not present.-->
#       </templatecontentitem>
#       <templatecontentitem row="7" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="370129005" csdConceptName="SCT" cmConceptName="Measurement Method" valueSetCID="7473" valueSetBDE="D"/>
#       <includetemplate row="8" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1402" name="VolumeMeasurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="7472" conceptNameBDE="D" unitsCID="7462" unitsBDE="D">
#       <!--Value shall be > 0, UNITS = DCID 7462-->
#       <templatecontentitem row="2" relationship="INFERRED FROM" valueType="SCOORD" vmmin="1" vmmax="n" requiredType="UC" cvConceptName="121057" csdConceptName="DCM" cmConceptName="Perimeter Outline">
#         <!--XOR Rows 5, 6-->
#         <templatecontentitem row="3" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 4-->
#         </templatecontentitem>
#         <templatecontentitem row="4" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 3-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="121191" csdConceptName="DCM" cmConceptName="Referenced Segment">
#         <!--XOR Rows 2, 6-->
#       </templatecontentitem>
#       <templatecontentitem row="6" relationship="R- INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="UC">
#         <!--XOR Rows 2, 5-->
#       </templatecontentitem>
#       <templatecontentitem row="7" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="370129005" csdConceptName="SCT" cmConceptName="Measurement Method" valueSetCID="7474" valueSetBDE="D"/>
#       <includetemplate row="8" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1404" name="NumericMeasurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" unitsCID="82" unitsBDE="D">
#       <templatecontentitem row="2" relationship="INFERRED FROM" valueType="SCOORD" vmmin="1" vmmax="n" requiredType="UC">
#         <!--XOR Rows 5, 6-->
#         <templatecontentitem row="3" relationship="R-SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 4-->
#         </templatecontentitem>
#         <templatecontentitem row="4" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC">
#           <!--XOR Row 3-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <templatecontentitem row="5" relationship="R-INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="n" requiredType="UC" conceptNameCID="7003" conceptNameBDE="B">
#         <!--XOR Rows 2, 6-->
#       </templatecontentitem>
#       <templatecontentitem row="6" relationship="INFERRED FROM" valueType="IMAGE" vmmin="1" vmmax="n" requiredType="UC" conceptNameCID="7003" conceptNameBDE="B">
#         <!--XOR Rows 2, 5-->
#       </templatecontentitem>
#       <includetemplate row="7" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1406" name="ThreeDimensionalLinearMeasurement" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="7470" conceptNameBDE="D" unitsCID="7460" unitsBDE="D">
#       <templatecontentitem row="2" relationship="INFERRED FROM" valueType="SCOORD3D" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121055" csdConceptName="DCM" cmConceptName="Path"/>
#       <includetemplate row="3" tid="4108" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="1410" name="PlanarROIMeasurementsandQualitativeEvaluations" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="125007" csdConceptName="DCM" cmConceptName="Measurement Group">
#       <templatecontentitem row="1b" relationship="HAS OBS CONTEXT" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="C67447" csdConceptName="NCIt" cmConceptName="Activity Session"/>
#       <templatecontentitem row="2" relationship="HAS OBS CONTEXT" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="112039" csdConceptName="DCM" cmConceptName="Tracking Identifier"/>
#       <templatecontentitem row="3" relationship="HAS OBS CONTEXT" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="112040" csdConceptName="DCM" cmConceptName="Tracking Unique Identifier"/>
#       <templatecontentitem row="3a" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="276214006" csdConceptName="SCT" cmConceptName="Finding category"/>
#       <templatecontentitem row="3b" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121071" csdConceptName="DCM" cmConceptName="Finding"/>
#       <templatecontentitem row="3c" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130400" csdConceptName="DCM" cmConceptName="Geometric purpose of region" valueSetCID="219" valueSetBDE="B"/>
#       <includetemplate row="4" tid="1502" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="5" relationship="CONTAINS" valueType="SCOORD" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="111030" csdConceptName="DCM" cmConceptName="Image Region">
#         <!--XOR Rows 7, 7b, 8b-->
#         <templatecontentitem row="6" relationship="SELECTED FROM" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="M"/>
#       </templatecontentitem>
#       <templatecontentitem row="7" relationship="CONTAINS" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121214" csdConceptName="DCM" cmConceptName="Referenced Segmentation Frame">
#         <!--Reference shall be to a Segmentation Image, with a single value specified in Referenced Segment Number (0062,000B)., For references to tiled Segmentation Images, one or more values shall be specified in Referenced Frame Number (0008,1160), unless all frames in the referenced Segmentation Image are selected and there is only a single Segment, in which case Referenced Frame Number (0008,1160) will be absent. The referenced tiles shall all be in the same plane., For references to non-tiled Segmentation Images, a single value shall be specified in Referenced Frame Number (0008,1160), unless there is only one frame in the referenced Segmentation Image, in which case Referenced Frame Number (0008,1160) will be absent.-->
#         <!--XOR Rows 5, 7b-->
#       </templatecontentitem>
#       <templatecontentitem row="7b" relationship="CONTAINS" valueType="SCOORD3D" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="111030" csdConceptName="DCM" cmConceptName="Image Region">
#         <!--XOR Rows 5, 7, 8b-->
#       </templatecontentitem>
#       <templatecontentitem row="8" relationship="CONTAINS" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="121233" csdConceptName="DCM" cmConceptName="Source image for segmentation">
#         <!--IFF Row 7-->
#       </templatecontentitem>
#       <templatecontentitem row="8b" relationship="CONTAINS" valueType="COMPOSITE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="130488" csdConceptName="DCM" cmConceptName="Region in Space">
#         <!--XOR Rows 5, 7, 7b-->
#         <templatecontentitem row="8c" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130489" csdConceptName="DCM" cmConceptName="Referenced Region of Interest Identifier"/>
#       </templatecontentitem>
#       <templatecontentitem row="9" relationship="CONTAINS" valueType="IMAGE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121200" csdConceptName="DCM" cmConceptName="Illustration of ROI"/>
# ...
#       <includetemplate row="5" tid="11003" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="MC"/>
#       <!--IF Row 4 = (130173, DCM, "Automated Administration")-->
#       <templatecontentitem row="6" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130240" csdConceptName="DCM" cmConceptName="Total Phase Volume Administered" cvUnits="ml" csdUnits="UCUM" cmUnits="ml"/>
#       <templatecontentitem row="7" relationship="CONTAINS" valueType="DATETIME" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="111526" csdConceptName="DCM" cmConceptName="">
#         <!--IFF root Concept Name Code Sequence = (130227, DCM, "Performed Imaging Agent Administration")-->
#       </templatecontentitem>
#       <templatecontentitem row="8" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="C0449238" csdConceptName="UMLS" cmConceptName="Duration" cvUnits="s" csdUnits="UCUM" cmUnits="s">
#         <!--IF root Concept Name Code Sequence = (130227, DCM, "Performed Imaging Agent Administration")AND Row 4 = (130173, DCM, "Automated Administration")-->
#       </templatecontentitem>
#       <templatecontentitem row="9" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="130264" csdConceptName="DCM" cmConceptName="IImaging Agent Administration Injector Phase Identifier">
#         <!--IFF root Concept Name Code Sequence = (130227, DCM, "Performed Imaging Agent Administration") AND Row 4 = (130173, DCM, "Automated Administration")-->
#       </templatecontentitem>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="11020" name="PerformedImagingAgentAdministration" root="T" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130227" csdConceptName="DCM" cmConceptName="Performed Imaging Agent Administration">
#       <includetemplate row="2" tid="1204" relationship="HAS CONCEPT MOD" vmmin="1" vmmax="1" requiredType="U"/>
#       <includetemplate row="3" tid="1002" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="n" requiredType="M"/>
#       <includetemplate row="4" tid="1005" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="U"/>
#       <includetemplate row="5" tid="8131" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="U"/>
#       <!--$DrugAdministered = DCID 65-->
#       <includetemplate row="6" tid="10024" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <includetemplate row="7" tid="11002" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="M"/>
#       <templatecontentitem row="8" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="55112-7" csdConceptName="LN" cmConceptName="Summary"/>
#       <includetemplate row="9" tid="11005" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="U"/>
#       <includetemplate row="10" tid="11006" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="M"/>
#       <templatecontentitem row="11" relationship="CONTAINS" valueType="COMPOSITE" vmmin="1" vmmax="1" requiredType="MC" cvConceptName="130236" csdConceptName="DCM" cmConceptName="Planned Imaging Agent Administration SOP Instance">
#         <!--IFF this administration was based on a Planned Imaging Agent Administration SOP Instance.-->
#       </templatecontentitem>
#       <templatecontentitem row="12" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130211" csdConceptName="DCM" cmConceptName="Imaging Agent Administration Completion Status" valueSetCID="67" valueSetBDE="D"/>
#       <includetemplate row="13" tid="11021" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <includetemplate row="14" tid="11022" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="15" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130165" csdConceptName="DCM" cmConceptName="" cvUnits="ml" csdUnits="UCUM" cmUnits="ml"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="11021" name="ImagingAgentAdministrationAdverseEvents" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130212" csdConceptName="DCM" cmConceptName="Imaging Agent Administration Adverse Events">
#       <templatecontentitem row="2" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130220" csdConceptName="DCM" cmConceptName="Administration discontinued" valueSetCID="231" valueSetBDE="D"/>
#       <templatecontentitem row="3" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="n" requiredType="M" cvConceptName="C41331" csdConceptName="NCIt" cmConceptName="Adverse Event" valueSetCID="60" valueSetBDE="D">
#         <templatecontentitem row="4" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="246112005" csdConceptName="SCT" cmConceptName="Severity" valueSetCID="3716" valueSetBDE="B"/>
#         <templatecontentitem row="5" relationship="HAS PROPERTIES" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="118578006" csdConceptName="SCT" cmConceptName="Relative Time" valueSetCID="61" valueSetBDE="D"/>
#         <templatecontentitem row="6" relationship="HAS PROPERTIES" valueType="DATETIME" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130215" csdConceptName="DCM" cmConceptName="Adverse Event Detection DateTime"/>
#         <templatecontentitem row="7" relationship="HAS PROPERTIES" valueType="NUM" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="130214" csdConceptName="DCM" cmConceptName="Estimated Extravasation Volume" cvUnits="ml" csdUnits="UCUM" cmUnits="ml">
#           <!--IF value of Row 3 = (95384003, SCT, "Injection Site Extravasation")-->
#         </templatecontentitem>
#         <templatecontentitem row="8" relationship="HAS OBS CONTEXT" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130216" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Administration Step UID"/>
#         <templatecontentitem row="9" relationship="HAS OBS CONTEXT" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130262" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Administration Phase UID"/>
#         <templatecontentitem row="10" relationship="HAS PROPERTIES" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121106" csdConceptName="DCM" cmConceptName="Comment"/>
#       </templatecontentitem>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="11022" name="ImagingAgentAdministrationInjectorEvents" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130233" csdConceptName="DCM" cmConceptName="Imaging Agent Administration Injector Events">
#       <templatecontentitem row="2" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130220" csdConceptName="DCM" cmConceptName="Administration discontinued" valueSetCID="231" valueSetBDE="D"/>
#       <templatecontentitem row="3" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="n" requiredType="M" cvConceptName="130234" csdConceptName="DCM" cmConceptName="Imaging Agent Administration Injector Event Type" valueSetCID="71" valueSetBDE="D">
#         <templatecontentitem row="4" relationship="HAS PROPERTIES" valueType="DATETIME" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130235" csdConceptName="DCM" cmConceptName="Injector Event Detection DateTime"/>
#         <templatecontentitem row="5" relationship="HAS OBS CONTEXT" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130216" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Administration Step UID"/>
#         <templatecontentitem row="6" relationship="HAS OBS CONTEXT" valueType="UIDREF" vmmin="1" vmmax="1" requiredType="U" cvConceptName="130262" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Administration Phase UID"/>
#         <templatecontentitem row="7" relationship="HAS OBS CONTEXT" valueType="TEXT" vmmin="1" vmmax="1" requiredType="UC" cvConceptName="130255" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Identifier">
#           <!--IFF there is more than one syringe and the syringe/pump can be identified.-->
#         </templatecontentitem>
#       </templatecontentitem>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="11023" name="ImagingAgentAdministrationGraph" root="F" extensible="T" ordersignificant="F">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130232" csdConceptName="DCM" cmConceptName="Imaging Agent Administration Graph">
#       <templatecontentitem row="2" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="M" cvConceptName="130255" csdConceptName="DCM" cmConceptName="Referenced Imaging Agent Identifier"/>
#       <includetemplate row="3" tid="3990" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="M"/>
#       <!--$MeasurementGraph = EV (130229, DCM, "Flow Rate vs time"), $X-Concept = EV (130194, DCM, "Time after the start of injection"), $Y-Concept = EV (122094, DCM, "Rate of administration"), $X-AxisUnit = DT (ms, UCUM,"ms"), $Y-AxisUnit = DT (ml/s, UCUM,"ml/s")-->
#       <includetemplate row="4" tid="3990" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <!--$MeasurementGraph = EV (130230, DCM, "Pressure vs Time"), $X-Concept = EV (130194, DCM, "Time after the start of injection"), $Y-Concept = EV (279046003, SCT, "Pressure"), $X-AxisUnit = DT (ms, UCUM,"ms"), $Y-AxisUnit = DT (kPa, UCUM,"kPa")-->
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="12000" name="GeneralUltrasoundReport" root="T" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" conceptNameCID="12320" conceptNameBDE="B">
#       <includetemplate row="2" tid="1204" relationship="HAS CONCEPT MOD" vmmin="1" vmmax="1" requiredType="U"/>
#       <includetemplate row="3" tid="1001" relationship="HAS OBS CONTEXT" vmmin="1" vmmax="1" requiredType="M"/>
#       <includetemplate row="4" tid="12001" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="5" relationship="CONTAINS" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="U" cvConceptName="55111-9" csdConceptName="LN" cmConceptName="Current Procedure Descriptions">
#         <templatecontentitem row="6" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="n" requiredType="M" cvConceptName="125203" csdConceptName="DCM" cmConceptName="Acquisition Protocol" valueSetCID="12001" valueSetBDE="B"/>
#         <templatecontentitem row="7" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113743" csdConceptName="DCM" cmConceptName="Patient Orientation" valueSetCID="19" valueSetBDE="D">
#           <templatecontentitem row="8" relationship="HAS CONCEPT MOD" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113744" csdConceptName="DCM" cmConceptName="Patient Orientation Modifier" valueSetCID="20" valueSetBDE="D"/>
#         </templatecontentitem>
#       </templatecontentitem>
#       <templatecontentitem row="9" relationship="CONTAINS" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="U" cvConceptName="18785-6" csdConceptName="LN" cmConceptName="Indications for Procedure">
#         <templatecontentitem row="10" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="121071" csdConceptName="DCM" cmConceptName="Finding">
#           <!--BCID 6051, BCID 12246, BCID 12325-->
#         </templatecontentitem>
#         <templatecontentitem row="11" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121071" csdConceptName="DCM" cmConceptName="Finding"/>
#       </templatecontentitem>
#       <templatecontentitem row="12" relationship="CONTAINS" valueType="CONTAINER" vmmin="1" vmmax="n" requiredType="U" cvConceptName="59776-5" csdConceptName="LN" cmConceptName="Findings">
#         <includetemplate row="13" tid="300" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="MC"/>
#         <!--IF Row 14 is not present-->
#         <templatecontentitem row="14" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="n" requiredType="MC" cvConceptName="121071" csdConceptName="DCM" cmConceptName="Finding">
#           <!--IF Row 13 is not present-->
#         </templatecontentitem>
#       </templatecontentitem>
#       <includetemplate row="15" tid="5401" relationship="CONTAINS" vmmin="1" vmmax="n" requiredType="U"/>
#     </templatecontentitem>
#   </definetemplate>
#   <definetemplate tid="12001" name="UltrasoundPatientCharacteristics" root="F" extensible="T" ordersignificant="T">
#     <templatecontentitem row="1" relationship="" valueType="CONTAINER" vmmin="1" vmmax="1" requiredType="M" cvConceptName="121118" csdConceptName="DCM" cmConceptName="Patient Characteristics">
#       <templatecontentitem row="2" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121033" csdConceptName="DCM" cmConceptName="Subject Age" unitsCID="7456" unitsBDE="D"/>
#       <templatecontentitem row="3" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121032" csdConceptName="DCM" cmConceptName="Subject Sex" valueSetCID="7455" valueSetBDE="D"/>
#       <templatecontentitem row="4" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="8302-2" csdConceptName="LN" cmConceptName="Patient Height" cvUnits="cm" csdUnits="UCUM" cmUnits="cm"/>
#       <templatecontentitem row="5" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="29463-7" csdConceptName="LN" cmConceptName="Patient Weight" cvUnits="kg" csdUnits="UCUM" cmUnits="kg"/>
#       <templatecontentitem row="6" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113550" csdConceptName="DCM" cmConceptName="Fasting Duration" cvUnits="h" csdUnits="UCUM" cmUnits="hours"/>
#       <templatecontentitem row="7" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="113552" csdConceptName="DCM" cmConceptName="Recent Physical Activity"/>
#       <templatecontentitem row="8" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="8867-4" csdConceptName="LN" cmConceptName="Heart Rate" cvUnits="{H.B.}/min" csdUnits="UCUM" cmUnits="BPM"/>
#       <templatecontentitem row="9" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="271649006" csdConceptName="SCT" cmConceptName="Systolic Blood Pressure" cvUnits="mm[Hg]" csdUnits="UCUM" cmUnits="mmHg"/>
#       <templatecontentitem row="10" relationship="CONTAINS" valueType="NUM" vmmin="1" vmmax="1" requiredType="U" cvConceptName="271650006" csdConceptName="SCT" cmConceptName="Diastolic Blood Pressure" cvUnits="mm[Hg]" csdUnits="UCUM" cmUnits="mmHg"/>
#       <templatecontentitem row="11" relationship="CONTAINS" valueType="CODE" vmmin="1" vmmax="n" requiredType="U" cvConceptName="260905004" csdConceptName="SCT" cmConceptName="Condition" valueSetCID="12323" valueSetBDE="B"/>
#       <includetemplate row="12" tid="3923" relationship="CONTAINS" vmmin="1" vmmax="1" requiredType="U"/>
#       <templatecontentitem row="13" relationship="CONTAINS" valueType="TEXT" vmmin="1" vmmax="1" requiredType="U" cvConceptName="121106" csdConceptName="DCM" cmConceptName="Comment"/>
#     </templatecontentitem>
#   </definetemplate>
# </definetemplates>

# %%
# Load the CSV data into a DataFrame
df = pd.read_csv('../P16_extract_srtemplates.csv')

# Display the first few rows of the DataFrame
df
# Out:
#        tid                                      name root extensible  \
# 0      300                               Measurement    F          T
# 1      310                     MeasurementProperties    F          T
# 2      311          MeasurementStatisticalProperties    F          T
# 3      312                     NormalRangeProperties    F          T
# 4      315                           EquationorTable    F          T
# ..     ...                                       ...  ...        ...
# 366  11021   ImagingAgentAdministrationAdverseEvents    F          T
# 367  11022  ImagingAgentAdministrationInjectorEvents    F          T
# 368  11023           ImagingAgentAdministrationGraph    F          T
# 369  12000                   GeneralUltrasoundReport    T          T
# 370  12001          UltrasoundPatientCharacteristics    F          T
#
#     ordersignificant  templatecontentitem  includetemplate
# 0                  T                  NaN              NaN
# 1                  T                  NaN              NaN
# 2                  T                  NaN              NaN
# 3                  T                  NaN              NaN
# 4                  T                  NaN              NaN
# ..               ...                  ...              ...
# 366                F                  NaN              NaN
# 367                F                  NaN              NaN
# 368                F                  NaN              NaN
# 369                T                  NaN              NaN
# 370                T                  NaN              NaN
#
# [371 rows x 7 columns]
